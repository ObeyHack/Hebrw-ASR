# %% [markdown]
# # Plot

# %%
# %pip install pandas
# %pip install matplotlib
# %pip install numpy

# %%
import pandas as pd
def plot_loss(df, y_max, title):
    # plot 2 columns for training and validation loss
    import matplotlib.pyplot as plt
    plt.plot(df['Train'], label='training')
    plt.plot(df['Val'], label='validation')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    # set y-axis limits
    plt.ylim([0, y_max])
    
    plt.legend()

    # set title
    plt.title(title)
    
    plt.show()

# %%
def plot_decoding(greedy, beam, beam_lm):
    import matplotlib.pyplot as plt
    import numpy as np

    labels = ['CER', 'WER']
    bars = {
    'Greedy': greedy,
    'Beam': beam,
    'Beam with LM': beam_lm
    }

    x = np.arange(len(labels))  # the laael locations
    width = 0.25  # the width of the bars
    multiplier = 0

    fig, ax = plt.subplots(layout='constrained')

    for attribute, measurement in bars.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, measurement, width, label=attribute)
        ax.bar_label(rects, padding=3)
        multiplier += 1

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title('Decoding Performance')
    ax.set_xticks(x + width, labels)

    # tight layout
    plt.tight_layout()

    ax.legend()
    plt.show()

# %% [markdown]
# # Simple NN - large scale

# %%
simple_nn_df = pd.read_csv('Simple_NN.csv')
plot_loss(simple_nn_df, 6, 'Simple NN Loss')

# %% [markdown]
# # Simple NN - small scale

# %%
simple_small_nn_df = pd.read_csv('simple_small.csv')
plot_loss(simple_small_nn_df, 20, 'Simple Small NN')

# %% [markdown]
# # DeepSpeech baseline

# %%
deep_nn_df = pd.read_csv('deep_nn.csv')
plot_loss(deep_nn_df, 15, 'Deep NN')

# %% [markdown]
# # Optimizer tuning

# %%
deep_tuned_nn_df = pd.read_csv('deep_tune_nn.csv')
plot_loss(deep_tuned_nn_df, 4, 'Deep Tuned NN')

# %% [markdown]
# # Decoding

# %%
# [CER, WER]
greedy = [0.43, 0.95]
beam = [0.58, 0.97]
beam_lm = [0.69, 0.92]
plot_decoding(greedy, beam, beam_lm)
# Out:
# /var/folders/34/23vz750518z3q304qcvg0ybw0000gn/T/ipykernel_18019/3490232749.py:29: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# # Data augmentation - Final model

# %%
final_df = pd.read_csv('final.csv')
plot_loss(final_df, 4, 'Final Model')
